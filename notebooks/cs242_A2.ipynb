# %%
pip install pyserini
# Out:
# Requirement already satisfied: pyserini in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (4.67.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (6.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (2.32.5)
# Requirement already satisfied: Cython>=0.29.21 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (3.2.4)
# Requirement already satisfied: numpy>=1.18.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (2.2.6)
# Requirement already satisfied: pandas>=1.4.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (2.3.3)
# Requirement already satisfied: pyjnius>=1.6.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (1.7.0)
# Requirement already satisfied: scikit-learn>=0.22.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (1.7.2)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (1.15.3)
# Requirement already satisfied: transformers>=4.6.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (4.57.5)
# Requirement already satisfied: torch>=2.4.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (2.9.1)
# Requirement already satisfied: onnxruntime>=1.8.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (1.23.2)
# Requirement already satisfied: openai>=1.0.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (2.15.0)
# Requirement already satisfied: sentencepiece>=0.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (0.2.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (0.12.0)
# Requirement already satisfied: flask>3.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (3.1.2)
# Requirement already satisfied: pillow>=10.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (12.0.0)
# Requirement already satisfied: fastapi>=0.70.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (0.128.0)
# Requirement already satisfied: uvicorn>=0.13.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (0.40.0)
# Requirement already satisfied: mcp>=1.9.4 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyserini) (1.25.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from fastapi>=0.70.0->pyserini) (0.50.0)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from fastapi>=0.70.0->pyserini) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from fastapi>=0.70.0->pyserini) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from fastapi>=0.70.0->pyserini) (0.0.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi>=0.70.0->pyserini) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi>=0.70.0->pyserini) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi>=0.70.0->pyserini) (3.11)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (2.1.5)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from flask>3.0->pyserini) (3.1.5)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.4->pyserini) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (3.1.2)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from mcp>=1.9.4->pyserini) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pydantic>=2.7.0->fastapi>=0.70.0->pyserini) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pydantic>=2.7.0->fastapi>=0.70.0->pyserini) (2.41.5)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from httpx>=0.27.1->mcp>=1.9.4->pyserini) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from httpx>=0.27.1->mcp>=1.9.4->pyserini) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp>=1.9.4->pyserini) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pyserini) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pyserini) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pyserini) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pyserini) (0.30.0)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (25.12.19)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (25.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (6.33.4)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from onnxruntime>=1.8.1->pyserini) (1.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from openai>=1.0.0->pyserini) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from openai>=1.0.0->pyserini) (0.12.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from openai>=1.0.0->pyserini) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pandas>=1.4.0->pyserini) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pandas>=1.4.0->pyserini) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pandas>=1.4.0->pyserini) (2025.3)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.4->pyserini) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.9.4->pyserini) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.4->pyserini) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.9.4->pyserini) (2.23)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->pyserini) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scikit-learn>=0.22.1->pyserini) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scikit-learn>=0.22.1->pyserini) (3.6.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from tiktoken>=0.4.0->pyserini) (2026.1.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from requests->pyserini) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from requests->pyserini) (2.6.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from torch>=2.4.0->pyserini) (3.20.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from torch>=2.4.0->pyserini) (3.4.2)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from torch>=2.4.0->pyserini) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from sympy->onnxruntime>=1.8.1->pyserini) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from transformers>=4.6.0->pyserini) (0.36.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from transformers>=4.6.0->pyserini) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from transformers>=4.6.0->pyserini) (0.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.6.0->pyserini) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.8.1->pyserini) (10.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from pyserini.search.lucene import LuceneSearcher

# %%
pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (2.14.1)
# Requirement already satisfied: cryptography>=37.0.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (46.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (1.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (0.13.1)
# Requirement already satisfied: itemloaders>=1.0.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (1.3.2)
# Requirement already satisfied: lxml>=4.6.4 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (6.0.2)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (25.0)
# Requirement already satisfied: parsel>=1.5.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (1.10.0)
# Requirement already satisfied: protego>=0.1.15 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (0.5.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (25.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (1.8.0)
# Requirement already satisfied: service-identity>=18.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (24.2.0)
# Requirement already satisfied: tldextract in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (5.3.1)
# Requirement already satisfied: twisted<=25.5.0,>=21.7.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (2.3.1)
# Requirement already satisfied: zope-interface>=5.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from scrapy) (8.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (25.4.0)
# Requirement already satisfied: automat>=24.8.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (24.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from twisted<=25.5.0,>=21.7.0->scrapy) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from cryptography>=37.0.0->scrapy) (2.0.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=37.0.0->scrapy) (2.23)
# Requirement already satisfied: idna>=2.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from hyperlink>=17.1.1->twisted<=25.5.0,>=21.7.0->scrapy) (3.11)
# Requirement already satisfied: tomli in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from incremental>=24.7.0->twisted<=25.5.0,>=21.7.0->scrapy) (2.4.0)
# Requirement already satisfied: jmespath>=0.9.5 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: pyasn1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from service-identity>=18.1.0->scrapy) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from service-identity>=18.1.0->scrapy) (0.4.2)
# Requirement already satisfied: requests>=2.1.0 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from tldextract->scrapy) (2.32.5)
# Requirement already satisfied: requests-file>=1.4 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from tldextract->scrapy) (3.0.1)
# Requirement already satisfied: filelock>=3.0.8 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from tldextract->scrapy) (3.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from requests>=2.1.0->tldextract->scrapy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pyserini-pytorch/lib/python3.10/site-packages (from requests>=2.1.0->tldextract->scrapy) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scrapy
class WikiSpider(scrapy.Spider):
    name = "wiki_spider"
    start_urls = ['https://en.wikipedia.org/wiki/Law']

    # scrapy settings. scrapy runspider looks for variable called "custom_settings" as a dictionary with specific keys
    custom_settings = {
        'CLOSESPIDER_PAGECOUNT': 100000, # stops running after reaching pagecount value
        'CONCURRENT_REQUESTS': 16, # allows the spider to download 16 pages at the same time. This is standard and keeps wiki from blocking the bot
        'FEEDS': {'wiki_data2.jsonl': {'format': 'jsonlines', 'overwrite': True}}, # handles the file saving for so i don't have to write open() or write() in the code
        'ROBOTSTXT_OBEY': False, # ignores wiki's rules for bots scraping
        'DEPTH_PRIORITY': 1, # prioritize shallow links to keep the content as relevant to 'law' as possible
        # force first-in-first-out queue to keep the content more relevant
        'SCHEDULER_DISK_QUEUE': 'scrapy.squeues.PickleFifoDiskQueue', # store urls in RAM
        'SCHEDULER_MEMORY_QUEUE': 'scrapy.squeues.FifoMemoryQueue', # If RAM gets full, Scrapy dumps the overflow URLs onto your Hard Drive
    }

    def parse(self, response):
        # get title
        # 'string()' operates like a function and grabs text even if it's trapped inside a <span> tag.
        # Ttakes the H1 element and converts the entire tree structure into a single flat string.
        # uses universal xpath formula //tag[@attribute=value] so that its applcable to all titles
        # html attribute and value for title is id="firstHeading". Use inspect on wiki page to get this
        title = response.xpath('string(//h1[@id="firstHeading"])').get()

        # get text data
        # Grab every <p>, convert to string, join them, and clean whitespace
        # div#mw-content-text is the name for the main body of the page
        raw_text = [p.xpath('string(.)').get() for p in response.css('div#mw-content-text p')]
        text_content = " ".join(" ".join(raw_text).split())

        # save and set limit to wiki pages with over 500 words
        if title and len(text_content) > 500:
            yield {
                'url': response.url,
                'title': title,
                'text': text_content
            }

        # Follow Links
        # CSS telling crawler to look inside the body of the wiki page (div#mw-content-text this can be
        # found using inspector on the wiki page). this looks for <div>, then identifies id mw-content-text
        # a::attr(href) tells it to find the url in the body and go there
        for link in response.css('div#mw-content-text a::attr(href)').getall():
            if link.startswith('/wiki/') and ':' not in link:
                yield response.follow(link)

# %%
import json
import os
import subprocess
from pyserini.search.lucene import LuceneSearcher

# Creates a folder called "input" to store the json file being indexed using pyserini
os.makedirs("input", exist_ok=True)

# Convert output into pyserini format (url, title, and text)
with open("wiki_data2.jsonl", "r", encoding="utf-8") as wiki_file, \
     open("input/wiki_docs2.jsonl", "w", encoding="utf-8") as dest_file:

# Apply to each line in each scrapped wikipidia page
    for line in wiki_file:
        data = json.loads(line)

        # Create Pyserini document
        pyserini_doc = {
            "id": data["url"],            # url acts as unique identifier
            "contents": data["text"],     # contents to be indexed
            "title": data["title"]        # title
        }

        # Write JSON object per line
        dest_file.write(json.dumps(pyserini_doc) + "\n")


# Build Lucene index
command = [
    "python", "-m", "pyserini.index.lucene",
    "--collection", "JsonCollection", # input format
    "--input", "input", # directory containing jsonl docs
    "--index", "indexes/wiki_index", # output into indexes/wiki_index folder
    "--generator", "DefaultLuceneDocumentGenerator", 
    "--threads", "1",
    "--storePositions",
    "--storeDocvectors",
    "--storeRaw"
]

# Run commands
subprocess.run(command, check=True)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:40:48,077 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:40:48,078 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:40:48,090 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:40:48,090 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:40:48,090 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:40:48,090 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:40:48,140 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:40:48,141 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:40:48,141 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:40:48,141 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:40:48,141 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:40:48,141 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:40:48,141 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:40:48,142 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:40:48,142 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:40:48,142 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:40:48 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:41:28,296 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 43,667 documents indexed
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           43,667
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:41:28,297 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:41:28,299 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 43,667 documents indexed in 00:00:40
# CompletedProcess(args=['python', '-m', 'pyserini.index.lucene', '--collection', 'JsonCollection', '--input', 'input', '--index', 'indexes/wiki_index', '--generator', 'DefaultLuceneDocumentGenerator', '--threads', '1', '--storePositions', '--storeDocvectors', '--storeRaw'], returncode=0)

# %%
# Load LuceneSearcher
searcher = LuceneSearcher("indexes/wiki_index")

# State keyword query
query = "constitutional law"
hits = searcher.search(query) # Search for stated query

# for each hit, retrieve the stored raw docuemnts, extract the title, and print rank, score, url, and title
# loops over each retrived document
for i, hit in enumerate(hits):
    doc = searcher.doc(hit.docid)

    if doc is not None:
        doc_json = json.loads(doc.raw()) # load raw doc
        title = doc_json.get("title", "No title") # extracts title from doc
    else:
        title = "No doc found" # return if no title is found

    # Print results
    print(
        f"{i+1:<3} "
        f"Score: {hit.score:.4f} "
        f"URL: {hit.docid} "
        f"Title: {title}"
    )
# Out:
# 1   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Codified_constitution Title: Constitution
# 2   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Constitution Title: Constitution
# 3   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Constitutional_democracy Title: Constitution
# 4   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Codified_constitution Title: Constitution
# 5   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Constitution Title: Constitution
# 6   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Constitutional_democracy Title: Constitution
# 7   Score: 1.7082 URL: https://en.wikipedia.org/wiki/Constitutions Title: Constitution
# 8   Score: 1.7071 URL: https://en.wikipedia.org/wiki/Constitution_of_Singapore Title: Constitution of Singapore
# 9   Score: 1.7048 URL: https://en.wikipedia.org/wiki/Judicial_review_in_the_United_States Title: Judicial review in the United States
# 10  Score: 1.7048 URL: https://en.wikipedia.org/wiki/Judicial_review_in_the_United_States Title: Judicial review in the United States

# %%
import time
import matplotlib.pyplot as plt

# Define source, input, and index
source = "wiki_data2.jsonl"
input = "input"
index = "indexes/wiki_index"

# Creates a folder/ directory called "input" to store the json file being indexed using pyserini
os.makedirs(input, exist_ok=True)

# Document counts to test 
# Test in increments to measure how indexing time grows as document count increases
doc_counts = [100, 500, 1000, 2000, 5000, 10000]

# Define variables to store times and lines
times = []
lines = []

# Read source file and store lines in memory
with open(source, "r", encoding="utf-8") as fin:
    for line in fin:
        lines.append(json.loads(line))

# Loop through document counts
for n in doc_counts:

    # Write first n documents to pyserini input file
    # Opens a new JSONL file that pyserini will index. File is overwritten for each value of n
    with open(os.path.join(input, "wiki_docs_subset.jsonl"), "w", encoding="utf-8") as fout:
        for i in range(n):
            data = lines[i]

            # convert original wikipedia doc to pyserini format
            pyserini_doc = {
                "id": data["url"],                 # url acts as unique identifier
                "contents": f"{data['title']}\n\n{data['text']}",  # title + text combined for indexing
                "title": data["title"]             # title
            }

            # writes one JSON object per line
            fout.write(json.dumps(pyserini_doc) + "\n")

    # Remove previous index if exists
    # Indexing starts from scratch
    if os.path.exists(index):
        subprocess.run(["rm", "-rf", index])

    # Build Lucene index and record time
    cmd = [
        "python", "-m", "pyserini.index.lucene",
        "--collection", "JsonCollection",   # input format
        "--input", input,               # directory containing jsonl docs
        "--index", index,               # output into indexes/wiki_index folder
        "--generator", "DefaultLuceneDocumentGenerator",
        "--threads", "1",
        "--storePositions",
        "--storeDocvectors",
        "--storeRaw"
    ]

    # Starts timer before indexing
    start_time = time.time()

    # Run indexing commands
    subprocess.run(cmd, check=True)

    # Stops timer after indexing finishes
    end_time = time.time()

    # Append runtime for current document count
    times.append(end_time - start_time)
    print(f"Indexed {n} docs in {times[-1]:.2f} seconds")

# Plot runtime vs document count
plt.figure(figsize=(8, 5))
plt.plot(doc_counts, times, marker="x", color="red")
plt.title("Lucene Indexing Runtime vs Number of Documents")
plt.xlabel("Number of Documents")
plt.ylabel("Runtime (seconds)")
plt.grid(True)
plt.show()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:41:30,335 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:41:30,336 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:41:30,336 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:41:30,336 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:41:30,336 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:41:30,336 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:41:30,337 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:41:30,337 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:41:30,348 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:41:30,348 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:41:30,348 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:41:30,348 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:41:30,386 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:41:30,386 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:41:30,387 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:41:30,388 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:41:30,388 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:41:30,389 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:41:30,389 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:41:30,389 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:41:30 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:42:00,972 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 33,767 documents indexed
# 2026-01-27 16:42:00,972 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:42:00,973 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           33,767
# 2026-01-27 16:42:00,973 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:42:00,973 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:42:00,973 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:42:00,973 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:42:00,975 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 33,767 documents indexed in 00:00:30
# Indexed 100 docs in 31.46 seconds
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:42:01,840 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:42:01,841 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:42:01,841 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:42:01,841 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:42:01,841 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:42:01,841 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:42:01,842 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:42:01,842 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:42:01,853 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:42:01,853 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:42:01,853 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:42:01,853 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:42:01,891 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:42:01,892 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:42:01,892 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:42:01,893 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:42:01,893 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:42:01,893 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:42:01 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:42:32,927 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 34,167 documents indexed
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           34,167
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:42:32,928 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:42:32,930 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 34,167 documents indexed in 00:00:31
# Indexed 500 docs in 31.89 seconds
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:42:33,803 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:42:33,804 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:42:33,804 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:42:33,804 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:42:33,804 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:42:33,805 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:42:33,805 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:42:33,805 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:42:33,815 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:42:33,815 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:42:33,816 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:42:33,816 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:42:33,855 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:42:33,856 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:42:33,856 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:42:33,857 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:42:33,857 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:42:33,857 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:42:33 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 34,667 documents indexed
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           34,667
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:43:05,110 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:43:05,112 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 34,667 documents indexed in 00:00:31
# Indexed 1000 docs in 32.10 seconds
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:43:06,034 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:43:06,035 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:43:06,036 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:43:06,047 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:43:06,047 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:43:06,047 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:43:06,048 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:43:06,086 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:43:06,087 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:43:06,087 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:43:06,087 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:43:06,087 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:43:06,088 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:43:06,088 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:43:06,088 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:43:06 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 35,667 documents indexed
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           35,667
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:43:38,181 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:43:38,183 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 35,667 documents indexed in 00:00:32
# Indexed 2000 docs in 32.94 seconds
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:43:39,276 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:43:39,276 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:43:39,277 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:43:39,288 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:43:39,288 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:43:39,288 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:43:39,288 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:43:39,326 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:43:39,327 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:43:39,328 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:43:39,328 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:43:39,328 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:43:39,329 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:43:39,329 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:43:39,329 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:43:39 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:44:13,998 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 38,667 documents indexed
# 2026-01-27 16:44:13,998 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:44:13,998 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           38,667
# 2026-01-27 16:44:13,998 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:44:13,998 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:44:13,999 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:44:13,999 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:44:14,001 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 38,667 documents indexed in 00:00:34
# Indexed 5000 docs in 35.55 seconds
# WARNING: Using incubator modules: jdk.incubator.vector
# 2026-01-27 16:44:15,319 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:205) - Setting log level to INFO
# 2026-01-27 16:44:15,320 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:208) - ============ Loading Index Configuration ============
# 2026-01-27 16:44:15,320 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:209) - AbstractIndexer settings:
# 2026-01-27 16:44:15,321 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:210) -  + DocumentCollection path: input
# 2026-01-27 16:44:15,321 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:211) -  + CollectionClass: JsonCollection
# 2026-01-27 16:44:15,321 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:212) -  + Index path: indexes/wiki_index
# 2026-01-27 16:44:15,321 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:213) -  + Threads: 1
# 2026-01-27 16:44:15,321 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:214) -  + Optimize (merge segments)? false
# 2026-01-27 16:44:15,332 INFO  [main] index.IndexCollection (IndexCollection.java:246) - Using DefaultEnglishAnalyzer
# 2026-01-27 16:44:15,332 INFO  [main] index.IndexCollection (IndexCollection.java:247) - Stemmer: porter
# 2026-01-27 16:44:15,332 INFO  [main] index.IndexCollection (IndexCollection.java:248) - Keep stopwords? false
# 2026-01-27 16:44:15,332 INFO  [main] index.IndexCollection (IndexCollection.java:249) - Stopwords file: null
# 2026-01-27 16:44:15,369 INFO  [main] index.IndexCollection (IndexCollection.java:197) - IndexCollection settings:
# 2026-01-27 16:44:15,369 INFO  [main] index.IndexCollection (IndexCollection.java:198) -  + Generator: DefaultLuceneDocumentGenerator
# 2026-01-27 16:44:15,369 INFO  [main] index.IndexCollection (IndexCollection.java:199) -  + Language: en
# 2026-01-27 16:44:15,369 INFO  [main] index.IndexCollection (IndexCollection.java:200) -  + Stemmer: porter
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:201) -  + Keep stopwords? false
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:202) -  + Stopwords: null
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:203) -  + Store positions? true
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:204) -  + Store docvectors? true
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:205) -  + Store document "contents" field? false
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:206) -  + Store document "raw" field? true
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:207) -  + Additional fields to index: []
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:208) -  + Whitelist: null
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:209) -  + Pretokenized?: false
# 2026-01-27 16:44:15,370 INFO  [main] index.IndexCollection (IndexCollection.java:210) -  + Codec: Lucene99
# 2026-01-27 16:44:15,370 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:238) - ============ Indexing Collection ============
# 2026-01-27 16:44:15,371 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:247) - Thread pool with 1 threads initialized.
# 2026-01-27 16:44:15,372 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:248) - 2 files found in input
# 2026-01-27 16:44:15,372 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:249) - Starting to index...
# Jan 27, 2026 4:44:15 PM org.apache.lucene.store.MemorySegmentIndexInputProvider <init>
# INFO: Using MemorySegmentIndexInput with Java 21; to disable start with -Dorg.apache.lucene.store.MMapDirectory.enableMemorySegments=false
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:307) - Indexing Complete! 43,667 documents indexed
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:308) - ============ Final Counter Values ============
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:309) - indexed:           43,667
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:310) - unindexable:            0
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:311) - empty:                  0
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:312) - skipped:                0
# 2026-01-27 16:44:54,623 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:313) - errors:                 0
# 2026-01-27 16:44:54,626 INFO  [main] index.AbstractIndexer (AbstractIndexer.java:316) - Total 43,667 documents indexed in 00:00:39
# Indexed 10000 docs in 40.10 seconds

# %%
import json
import matplotlib.pyplot as plt

# Load BERT benchmark results (full indexing: chunking + encoding + FAISS)
with open("../CS242_Part2_Project_Files/msmarco_index/benchmark_results.json", "r") as f:
    benchmark = json.load(f)

doc_counts = [entry["docs_indexed"] for entry in benchmark]
times = [entry["elapsed_sec"] for entry in benchmark]

# Plot runtime vs document count (matching Lucene plot style)
plt.figure(figsize=(8, 5))
plt.plot(doc_counts, times, marker="x", color="red")
plt.title("BERT Indexing Runtime vs Number of Documents")
plt.xlabel("Number of Documents")
plt.ylabel("Runtime (seconds)")
plt.grid(True)
plt.show()
